# %% [markdown]
# L'inconvénient avec cette approche est que si le lieu spécifié n'est pas reconnu, alors, on n'arrive pas à extraire des informations.

# %%
import requests
import geopandas as gpd
import folium
from shapely.geometry import Point

# Définir l'URL de l'API Overpass pour récupérer les données géospatiales
overpass_url = "https://overpass-api.de/api/interpreter"

# Définir la requête Overpass pour Youssoufia avec différents types de points d'intérêt
overpass_query = """
    [out:json];
    area[name="Youssoufia"]->.searchArea;
    (
        node["amenity"="pharmacy"](area.searchArea);
        node["name"="La Poste"](area.searchArea);
        node["name"="YouCode"](area.searchArea);
    );
    out center;
"""

# Envoyer la requête à l'API Overpass
response = requests.get(overpass_url, params={'data': overpass_query})

# Vérifier si la requête a réussi (statut 200 indique succès)
if response.status_code == 200:
    # Convertir la réponse JSON en un dictionnaire Python
    data = response.json()
    
    # Créer des listes de dictionnaires contenant les informations sur les différentes catégories
    pharmacies_data = []
    la_poste_data = []
    youcode_data = []
    
    for element in data['elements']:
        if element.get('tags', {}).get('amenity') == 'pharmacy':
            pharmacies_data.append({
                'name': element.get('tags', {}).get('name'),
                'latitude': element.get('lat'),
                'longitude': element.get('lon')
            })
        
        elif element.get('tags', {}).get('name') == 'La Poste':
            la_poste_data.append({
                'name': element.get('tags', {}).get('name'),
                'latitude': element.get('lat'),
                'longitude': element.get('lon')
            })
        elif element.get('tags', {}).get('name') == 'YouCode':
            youcode_data.append({
                'name': element.get('tags', {}).get('name'),
                'latitude': element.get('lat'),
                'longitude': element.get('lon')
            })
    
    # Créer des GeoDataFrames à partir des données pour chaque catégorie
    pharmacies_gdf = gpd.GeoDataFrame(pharmacies_data, geometry=gpd.points_from_xy([p['longitude'] for p in pharmacies_data], [p['latitude'] for p in pharmacies_data]))
    la_poste_gdf = gpd.GeoDataFrame(la_poste_data, geometry=gpd.points_from_xy([lp['longitude'] for lp in la_poste_data], [lp['latitude'] for lp in la_poste_data]))
    youcode_gdf = gpd.GeoDataFrame(youcode_data, geometry=gpd.points_from_xy([y['longitude'] for y in youcode_data], [y['latitude'] for y in youcode_data]))
    
    # Créer une carte Folium centrée sur les pharmacies (vous pouvez choisir une autre catégorie si vous le souhaitez)
    m = folium.Map(location=[pharmacies_gdf['latitude'].mean(), pharmacies_gdf['longitude'].mean()], zoom_start=14)
    
    # Ajouter les marqueurs des pharmacies sur la carte
    for idx, row in pharmacies_gdf.iterrows():
        folium.Marker([row['latitude'], row['longitude']], popup=row['name']).add_to(m)
    
    # Ajouter les marqueurs de La Poste sur la carte
    for idx, row in la_poste_gdf.iterrows():
        folium.Marker([row['latitude'], row['longitude']], popup=row['name'], icon=folium.Icon(color='yellow')).add_to(m)
    
    # Ajouter les marqueurs de YouCode sur la carte
    for idx, row in youcode_gdf.iterrows():
        folium.Marker([row['latitude'], row['longitude']], popup=row['name'], icon=folium.Icon(color='purple')).add_to(m)
    
    # Afficher la carte
    display(m)
else:
    print("La requête a échoué. Statut :", response.status_code)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b60758eeb338ab5fd7e9b745cf5da410 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b60758eeb338ab5fd7e9b745cf5da410&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b60758eeb338ab5fd7e9b745cf5da410 = L.map(
#                 &quot;map_b60758eeb338ab5fd7e9b745cf5da410&quot;,
#                 {
#                     center: [32.24527983478261, -8.534229226086957],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_09c6e3b6c23b950da322435643a43694 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b60758eeb338ab5fd7e9b745cf5da410);
#
#
#             var marker_fdf0a140cf0f1671952f512fbfe65457 = L.marker(
#                 [32.2330557, -8.5366846],
#                 {}
#             ).addTo(map_b60758eeb338ab5fd7e9b745cf5da410);
#
#
#         var popup_f27c2fec5366cb5bdbc96150564030e4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_36121874ffd45ebba601e1ff2b1b3e09 = $(`&lt;div id=&quot;html_36121874ffd45ebba601e1ff2b1b3e09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pharmacie Dakhla صيدلية الداخلة&lt;/div&gt;`)[0];
#                 popup_f27c2fec5366cb5bdbc96150564030e4.setContent(html_36121874ffd45ebba601e1ff2b1b3e09);
#
#
#
#         marker_fdf0a140cf0f1671952f512fbfe65457.bindPopup(popup_f27c2fec5366cb5bdbc96150564030e4)
#         ;
#
#
#
#
#             var marker_adae03af53ead3976b83502f55d37364 = L.marker(
#                 [32.2353451, -8.5328651],
#                 {}
#             ).addTo(map_b60758eeb338ab5fd7e9b745cf5da410);
#
#
#         var popup_a5e41f299e80ddbfcea0b82fc4d7cdb3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_49441fa32336e50780fc912388692208 = $(`&lt;div id=&quot;html_49441fa32336e50780fc912388692208&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pharmacie Al Amal صيدلية الأمل&lt;/div&gt;`)[0];
#                 popup_a5e41f299e80ddbfcea0b82fc4d7cdb3.setContent(html_49441fa32336e50780fc912388692208);
#
#
#
#         marker_adae03af53ead3976b83502f55d37364.bindPopup(popup_a5e41f299e80ddbfcea0b82fc4d7cdb3)
#         ;
#
#
#
#
#             var marker_51e888bd88e901c99f6edc863ac49065 = L.marker(
#                 [32.2361437, -8.5360301],
#                 {}
#             ).addTo(map_b60758eeb338ab5fd7e9b745cf5da410);
#
#
#         var popup_15b6338867fa9d9fbbc194795eb77e27 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a874ad10beb632b5f169a307b02825f3 = $(`&lt;div id=&quot;html_a874ad10beb632b5f169a307b02825f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pharmacie Saada Rhazri صيدلية السعادة عازري&lt;/div&gt;`)[0];
#                 popup_15b6338867fa9d9fbbc194795eb77e27.setContent(html_a874ad10beb632b5f169a307b02825f3);
#
#
#
#         marker_51e888bd88e901c99f6edc863ac49065.bindPopup(popup_15b6338867fa9d9fbbc194795eb77e27)
#         ;
#
#
#
#
#             var marker_470d657bb25a4e0850151147895417b0 = L.marker(
#                 [32.237092, -8.5326451],
#                 {}
#             ).addTo(map_b60758eeb338ab5fd7e9b745cf5da410);
#
#
#         var popup_80378cbbf02ab79e0d4ffa3dff5ceacc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_96435ef0331291c6e6a4af64be3db114 = $(`&lt;div id=&quot;html_96435ef0331291c6e6a4af64be3db114&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pharmacie Annour صيدلية النور&lt;/div&gt;`)[0];
#                 popup_80378cbbf02ab79e0d4ffa3dff5ceacc.setContent(html_96435ef0331291c6e6a4af64be3db114);
#
#
#
#         marker_470d657bb25a4e0850151147895417b0.bindPopup(popup_80378cbbf02ab79e0d4ffa3dff5ceacc)
#         ;
#
#
#
#
#             var marker_c6687dcd3079ab8fe094ce7d84d77df7 = L.marker(
#                 [32.2415859, -8.5371963],
#                 {}
#             ).addTo(map_b60758eeb338ab5fd7e9b745cf5da410);
#
#
#         var popup_d250457ca3713320ec00891ae2cefd64 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b29bcd73c3755193416c2ab4d7fdfa82 = $(`&lt;div id=&quot;html_b29bcd73c3755193416c2ab4d7fdfa82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pharmacie Moderne الصيدلية الحديثة&lt;/div&gt;`)[0];
#                 popup_d250457ca3713320ec00891ae2cefd64.setContent(html_b29bcd73c3755193416c2ab4d7fdfa82);
#
#
#
#         marker_c6687dcd3079ab8fe094ce7d84d77df7.bindPopup(popup_d250457ca3713320ec00891ae2cefd64)
#         ;
